# %%
from vnpy.trader.app.ctaStrategy import BacktestingEngine
import pandas as pd

# %% [markdown]
# 策略编写步骤
# 设置回测模式，日期，品种数据
# 设置品种，手续费，滑点
# 设置策略参数
# 初始化策略
# 编写指标信号
# 下单执行
# 执行回测
# 显示回测结果

# %%
#创建回测引擎
engine= BacktestingEngine()
engine.setDB_URI("mongodb://localhost:27017")
#设置回测模式
engine.setBacktestingMode(engine.BAR_MODE)
engine.setDatabase('VnTrader_1Min_Db')
# 设置回测日期，initHours 默认值为 0
engine.setStartDate('20180201 23:00:00',initHours=10)
engine.setEndDate('20190320 23:00:00')
#设置交易品种，手续费，滑点
engine.setCapital(10000000)
constracts=[{"symbol":"IF88:CTP",
                "size" : 1, # 每点价值
                "priceTick" : 0.1, # 最小价格变动
                "rate" : 5/10000, # 单边手续费
                "slippage" : 0.1 # 滑价
            },]
engine.setContracts(constracts)
settingList = [{
                "symbolList": ["IF88:CTP"]
                }]

# %%
from vnpy.trader.vtConstant import *
from vnpy.trader.app.ctaStrategy import CtaTemplate
import talib as ta
from datetime import datetime
#策略继承ctaTemplate
class DoubleMaStrategy(CtaTemplate):
    """双指数均线策略Demo"""
    className = 'DoubleMaStrategy'
    author = 'ChannelCMT'
    symbolList = ["IF88:CTP"]
    #策略参数
    fastPeriod=20
    slowPeriod=55
    lot=1#设置手数
    #策略变量
    transactionPrice=None
    paramList=['fastPeriod','slowPeriod']
    #策略变量列表
    varList=['transactionPrice']
    # 同步列表，保存了需要保存到数据库的变量名称
    syncList = ['posDict', 'eveningDict']
    def __init__(self, ctaEngine, setting):
        super().__init__(ctaEngine, setting)
    # 首先找到策略的父类（就是类CtaTemplate），然后把DoubleMaStrategy的对象转换为类CtaTemplate的对象?????????
    def onInit(self):
        """初始化策略"""
        self.transactionPrice={s:0 for s in self.symbolList}#生成成交价格的字典
        self.chartLog= {
                        'datetime':[],
                        'fastMa':[],
                        'slowMa':[]
                        }
        self.putEvent()
    
    def onStart(self):
        """启动策略（必须由用户继承实现）"""
        self.writeCtaLog(u'策略启动')
        self.putEvent()
    def onStop(self):
        self.writeCtaLog(u'策略停止')
        self.putEvent()
    def onTick(self, tick):
        """收到行情TICK推送"""
        pass
    def on60MinBar(self, bar):
        """收到60分钟Bar推送"""
        symbol = bar.vtSymbol
        am60 = self.getArrayManager(symbol, "60m") # 获取历史数组
        if not am60.inited:
            return
        # 计算策略需要的信号-------------------------------------------------
        fastMa=ta.EMA(am60.close,self.fastPeriod)
        slowMa=ta.EMA(am60.close,self.slowPeriod)
        self.chartLog['datetime'].append(datetime.strptime(am60.datetime[-1], "%Y%m%d %H:%M:%S"))
        self.chartLog['fastMa'].append(fastMa[-1])
        self.chartLog['slowMa'].append(slowMa[-1])
        #设置交易条件
        crossOver=(fastMa[-1]>slowMa[-1]) and (fastMa[-2]<=slowMa[-2])
        crossBlow=(fastMa[-1]<slowMa[-1]) and (fastMa[-2]>=slowMa[-2])
         # 构建进出场逻辑-------------------------------------------------
        # 如果金叉时手头没有多头持仓
        if (crossOver) and (self.posDict[symbol+'_LONG']==0):
            if self.posDict[symbol+'_SHORT']==0:
                self.buy(symbol,bar.close*1.01,self.lot)
            elif self.posDict[symbol+'_SHORT']>0:
                self.cancelAll()#撤销挂单，撤销要卖出的单子
                self.cover(symbol,bar.close*1.01,self.posDict[symbol+'_SHORT'])
                self.buy(symbol,bar.close*1.01,self.lot)
        #如果死叉时候没有空头持仓
        elif (crossBlow) and (self.posDict[symbol+'_SHORT']==0):
            if self.posDict[symbol+'_LONG']==0:
                self.short(symbol,bar.close*0.99,self.lot)
            elif self.posDict[symbol+'_LONG']>0:
                self.cancelAll()
                self.cover(symbol,bar.close*0.99,self.posDict[symbol+'_LONG'])
                self.short(symbol,bar.close*0.99,self.lot)
        self.putEvent()
    def onOrder(self, order):
        """收到委托变化推送"""
        # 对于无需做细粒度委托控制的策略，可以忽略onOrder
        pass
    
    #----------------------------------------------------------------------
    def onTrade(self, trade):
        """收到成交推送"""
        symbol = trade.vtSymbol
        if trade.offset == OFFSET_OPEN:  # 判断成交订单类型
            self.transactionPrice = trade.price # 记录成交价格
    #----------------------------------------------------------------------
    def onStopOrder(self, so):
        """停止单推送"""
        pass

# %%
from vnpy.trader.utils import htmlplot
engine.setLog(True, "./log")
engine.initStrategy(DoubleMaStrategy, settingList[0])
# 开始跑回测
engine.runBacktesting()
# Out:
# 初始仓位: {'IF88:CTP_LONG': 0, 'IF88:CTP_SHORT': 0}
# 2019-05-17 20:13:41.440579	开始回测
# 2019-05-17 20:13:41.441581	策略初始化
# 2019-05-17 20:13:41.445592	准备载入数据：时间段:[20180201 13:00:00 , 20180201 23:00:00), 模式: bar
# 2019-05-17 20:13:41.466648	IF88:CTP： 从本地缓存文件实取120, 最大应取600, 还需从数据库取480
# 2019-05-17 20:13:41.481686	IF88:CTP： 数据库也没能补到缺失的数据
# 2019-05-17 20:13:41.482691	载入完成, 数据量:120
# 2019-05-17 20:13:41.482691	初始化预加载数据成功, 数据长度:120
# 2019-05-17 20:13:41.482691	策略初始化完成
# 2019-05-17 20:13:41.483693	策略启动完成
# 2019-05-17 20:13:41.483693	回测时间范围:[20180201 23:00:00,20190320 23:00:00)
# 2019-05-17 20:13:41.483693	当前回放的时间段:[20180201 23:00:00,20190320 23:00:00)
# 2019-05-17 20:13:43.887381	准备载入数据：时间段:[20180201 23:00:00 , 20190320 23:00:00), 模式: bar
# 2019-05-17 20:13:51.385326	IF88:CTP： 从本地缓存文件实取65040, 最大应取593280, 还需从数据库取528240
# 2019-05-17 20:13:53.794735	IF88:CTP： 数据库也没能补到缺失的数据
# 2019-05-17 20:13:53.812803	载入完成, 数据量:65040
# 2019-05-17 20:13:53.871960	准备载入数据：时间段:[20180201 07:51:00 , 20180203 23:01:00), 模式: bar
# 2019-05-17 20:13:53.936111	IF88:CTP： 从本地缓存文件实取480, 最大应取3790, 还需从数据库取3310
# 2019-05-17 20:13:53.958171	IF88:CTP： 数据库也没能补到缺失的数据
# 2019-05-17 20:13:53.959175	载入完成, 数据量:480
# 2019-05-17 20:13:54.189869	准备载入数据：时间段:[20171226 02:00:00 , 20180201 07:50:00), 模式: bar
# 2019-05-17 20:13:54.972925	IF88:CTP： 从本地缓存文件实取6240, 最大应取53630, 还需从数据库取47390
# 2019-05-17 20:13:55.163543	IF88:CTP： 数据库也没能补到缺失的数据
# 2019-05-17 20:13:55.165543	载入完成, 数据量:6240
# 2019-05-17 20:13:55.171540	准备载入数据：时间段:[20180203 23:02:00 , 20180204 00:00:00), 模式: bar
# 2019-05-17 20:13:55.171540	IF88:CTP： 从本地缓存文件实取0, 最大应取58, 还需从数据库取58
# 2019-05-17 20:13:55.198614	IF88:CTP： 数据库也没能补到缺失的数据
# 2019-05-17 20:13:55.198614	WARNING: 该时间段:[20180203 23:02:00,20180204 00:00:00) 数据量为0!
# 2019-05-17 20:13:56.126163	当前order：20180322 13:59:00, 买平1, 可平0, 实盘下可能拒单, 请小心处理
# 2019-05-17 20:13:56.932964	当前order：20180525 11:29:00, 买平1, 可平0, 实盘下可能拒单, 请小心处理
# 2019-05-17 20:13:57.875458	当前order：20180802 13:59:00, 买平1, 可平0, 实盘下可能拒单, 请小心处理
# 2019-05-17 20:13:58.292869	当前order：20180903 11:29:00, 买平1, 可平0, 实盘下可能拒单, 请小心处理
# 2019-05-17 20:13:58.684931	当前order：20181010 11:29:00, 买平1, 可平0, 实盘下可能拒单, 请小心处理
# 2019-05-17 20:13:59.272641	当前order：20181123 11:29:00, 买平1, 可平0, 实盘下可能拒单, 请小心处理
# 2019-05-17 20:13:59.476164	当前order：20181210 10:59:00, 买平1, 可平0, 实盘下可能拒单, 请小心处理
# 2019-05-17 20:14:00.698565	回放结束ress: 100%
# 2019-05-17 20:14:00.700562	Backtest log Recorded

# %% [markdown]
# # def initStrategy(self, strategyClass, setting=None):
#         """
#         初始化策略
#         setting是策略的参数设置，如果使用类中写好的默认设置则可以不传该参数
#         """
#         self.strategy = strategyClass(self, setting)
#         self.strategy.name = self.strategy.className
#         self.strategy.symbolList = setting['symbolList']
#         self.initPosition(self.strategy)

# %%
#显示回测的每张订单数
engine.showBacktestingResult()
# Out:
# 2019-05-17 20:24:46.640569	计算回测结果
# 2019-05-17 20:24:46.656612	交割单已生成
# 2019-05-17 20:24:46.657615	------------------------------
# 2019-05-17 20:24:46.657615	第一笔交易：	2018-03-23 09:30:00
# 2019-05-17 20:24:46.657615	最后一笔交易：	2019-03-20 14:58:00
# 2019-05-17 20:24:46.658618	总交易次数：	8
# 2019-05-17 20:24:46.658618	总盈亏：	67.18
# 2019-05-17 20:24:46.659621	最大回撤: 	-300.18
# 2019-05-17 20:24:46.659621	平均每笔盈利：	8.4
# 2019-05-17 20:24:46.660623	平均每笔滑点：	0.2
# 2019-05-17 20:24:46.660623	平均每笔佣金：	3.48
# 2019-05-17 20:24:46.661625	胜率		87.5%
# 2019-05-17 20:24:46.661625	盈利交易平均值	52.48
# 2019-05-17 20:24:46.661625	亏损交易平均值	-300.18
# 2019-05-17 20:24:46.661625	盈亏比：	0.17
# 2019-05-17 20:24:47.023951	策略回测统计图已保存

# %%
# 显示回测的每日绩效
engine.showDailyResult()
# Out:
# 2019-05-17 20:25:42.543961	计算按日统计结果
# 2019-05-17 20:25:42.612218	------------------------------
# 2019-05-17 20:25:42.612218	首个交易日：	2018-02-02
# 2019-05-17 20:25:42.612218	最后交易日：	2019-03-20
# 2019-05-17 20:25:42.612218	总交易日：	271
# 2019-05-17 20:25:42.612218	盈利交易日	115
# 2019-05-17 20:25:42.612218	亏损交易日：	127
# 2019-05-17 20:25:42.612218	起始资金：	10000000
# 2019-05-17 20:25:42.612218	结束资金：	10,000,069.2
# 2019-05-17 20:25:42.612218	总收益率：	0.0%
# 2019-05-17 20:25:42.612218	年化收益：	0.0%
# 2019-05-17 20:25:42.612218	总盈亏：	69.2
# 2019-05-17 20:25:42.612218	最大回撤: 	-805.0
# 2019-05-17 20:25:42.612218	百分比最大回撤: -0.01%
# 2019-05-17 20:25:42.612218	总手续费：	25.9
# 2019-05-17 20:25:42.612218	总滑点：	1.5
# 2019-05-17 20:25:42.612218	总成交金额：	51,803.8
# 2019-05-17 20:25:42.612218	总成交笔数：	15
# 2019-05-17 20:25:42.612951	日均盈亏：	0.26
# 2019-05-17 20:25:42.612951	日均手续费：	0.1
# 2019-05-17 20:25:42.612951	日均滑点：	0.01
# 2019-05-17 20:25:42.612951	日均成交金额：	191.16
# 2019-05-17 20:25:42.612951	日均成交笔数：	0.06
# 2019-05-17 20:25:42.612951	日均收益率：	0.0%
# 2019-05-17 20:25:42.612951	收益标准差：	0.0%
# 2019-05-17 20:25:42.612951	Sharpe Ratio：	0.08
# 2019-05-17 20:25:44.937695	策略回测绩效图已保存
# 2019-05-17 20:25:44.939700	BacktestingResult saved

# %%
chartLog=pd.DataFrame(engine.strategy.chartLog).set_index('datetime')
mp = htmlplot.getMultiPlot(engine, freq="60m")
mp.set_line(line=chartLog[['fastMa', 'slowMa']], colors={"fastMa": "red",'slowMa':'blue'}, pos=0)
mp.show()

# %% [markdown]
# 优化策略参数
# 单线程运行优化
# 多线程优化

# %%
from vnpy.trader.app.ctaStrategy.ctaBacktesting  import OptimizationSetting
#优化配置
setting=OptimizationSetting()
engine.setLog(False)
setting.setOptimizeTarget('sharpeRatio')
setting.addParameter('fastPeriod', 20, 40, 10)    # 增加第一个优化参数，起始30，结束50，步进10
setting.addParameter('slowPeriod', 40, 80, 20)    # 增加第二个优化参数，起始60，结束30，步进10
setting.addParameter('symbolList', ['IF88:CTP'])

# %%
import time
start = time.time()
# 执行单线程优化
resultList = engine.runOptimization(DoubleMaStrategy, setting)

print('耗时：%s' %(time.time()-start))
# Out:
# 2019-05-17 20:54:42.662822	------------------------------
# 2019-05-17 20:54:42.662822	setting: {'fastPeriod': 20, 'slowPeriod': 40, 'symbolList': ['IF88:CTP']}
# 初始仓位: {'IF88:CTP_LONG': 0, 'IF88:CTP_SHORT': 0}
# 2019-05-17 20:54:42.663826	开始回测
# 2019-05-17 20:54:42.663826	策略初始化
# 2019-05-17 20:54:42.666833	准备载入数据：时间段:[20180201 13:00:00 , 20180201 23:00:00), 模式: bar
# 2019-05-17 20:54:42.691898	IF88:CTP： 从本地缓存文件实取120, 最大应取600, 还需从数据库取480
# 2019-05-17 20:54:42.714959	IF88:CTP： 数据库也没能补到缺失的数据
# 2019-05-17 20:54:42.714959	载入完成, 数据量:120
# 2019-05-17 20:54:42.714959	初始化预加载数据成功, 数据长度:120
# 2019-05-17 20:54:42.714959	策略初始化完成
# 2019-05-17 20:54:42.714959	策略启动完成
# 2019-05-17 20:54:42.714959	回测时间范围:[20180201 23:00:00,20190320 23:00:00)
# 2019-05-17 20:54:42.714959	当前回放的时间段:[20180201 23:00:00,20190320 23:00:00)
# 2019-05-17 20:54:45.174560	准备载入数据：时间段:[20180201 23:00:00 , 20190320 23:00:00), 模式: bar
# 2019-05-17 20:54:53.361523	IF88:CTP： 从本地缓存文件实取65040, 最大应取593280, 还需从数据库取528240
# 2019-05-17 20:54:56.142920	IF88:CTP： 数据库也没能补到缺失的数据
# 2019-05-17 20:54:56.172021	载入完成, 数据量:65040
# 2019-05-17 20:54:56.254243	准备载入数据：时间段:[20180201 07:51:00 , 20180203 23:01:00), 模式: bar
# 2019-05-17 20:54:56.310366	IF88:CTP： 从本地缓存文件实取480, 最大应取3790, 还需从数据库取3310
# 2019-05-17 20:54:56.340451	IF88:CTP： 数据库也没能补到缺失的数据
# 2019-05-17 20:54:56.340451	载入完成, 数据量:480
# 2019-05-17 20:54:56.586091	准备载入数据：时间段:[20171226 02:00:00 , 20180201 07:50:00), 模式: bar
# 2019-05-17 20:54:57.318800	IF88:CTP： 从本地缓存文件实取6240, 最大应取53630, 还需从数据库取47390
# 2019-05-17 20:54:57.488227	IF88:CTP： 数据库也没能补到缺失的数据
# 2019-05-17 20:54:57.491236	载入完成, 数据量:6240
# 2019-05-17 20:54:57.496249	准备载入数据：时间段:[20180203 23:02:00 , 20180204 00:00:00), 模式: bar
# 2019-05-17 20:54:57.496249	IF88:CTP： 从本地缓存文件实取0, 最大应取58, 还需从数据库取58
# 2019-05-17 20:54:57.511292	IF88:CTP： 数据库也没能补到缺失的数据
# 2019-05-17 20:54:57.512292	WARNING: 该时间段:[20180203 23:02:00,20180204 00:00:00) 数据量为0!
# 2019-05-17 20:54:58.509758	当前order：20180322 10:59:00, 买平1, 可平0, 实盘下可能拒单, 请小心处理
# 2019-05-17 20:54:58.790499	当前order：20180412 14:59:00, 买平1, 可平0, 实盘下可能拒单, 请小心处理
# 2019-05-17 20:54:59.359034	当前order：20180524 13:59:00, 买平1, 可平0, 实盘下可能拒单, 请小心处理
# 2019-05-17 20:54:59.583607	当前order：20180608 10:59:00, 买平1, 可平0, 实盘下可能拒单, 请小心处理
# 2019-05-17 20:55:00.126070	当前order：20180719 11:29:00, 买平1, 可平0, 实盘下可能拒单, 请小心处理
# 2019-05-17 20:55:00.777161	当前order：20180903 13:59:00, 买平1, 可平0, 实盘下可能拒单, 请小心处理
# 2019-05-17 20:55:01.235399	当前order：20181010 10:59:00, 买平1, 可平0, 实盘下可能拒单, 请小心处理
# 2019-05-17 20:55:01.980708	当前order：20181122 14:59:00, 买平1, 可平0, 实盘下可能拒单, 请小心处理
# 2019-05-17 20:55:02.202738	当前order：20181210 10:59:00, 买平1, 可平0, 实盘下可能拒单, 请小心处理
# 2019-05-17 20:55:03.389898	回放结束ress: 100%
# 2019-05-17 20:55:03.389898	计算按日统计结果
# 2019-05-17 20:55:03.450076	------------------------------
# 2019-05-17 20:55:03.451079	setting: {'fastPeriod': 20, 'slowPeriod': 60, 'symbolList': ['IF88:CTP']}
# 初始仓位: {'IF88:CTP_LONG': 0, 'IF88:CTP_SHORT': 0}
# 2019-05-17 20:55:03.454085	开始回测
# 2019-05-17 20:55:03.454085	策略初始化
# 2019-05-17 20:55:03.456091	准备载入数据：时间段:[20180201 13:00:00 , 20180201 23:00:00), 模式: bar
# 2019-05-17 20:55:03.478150	IF88:CTP： 从本地缓存文件实取120, 最大应取600, 还需从数据库取480
# 2019-05-17 20:55:03.492192	IF88:CTP： 数据库也没能补到缺失的数据
# 2019-05-17 20:55:03.492192	载入完成, 数据量:120
# 2019-05-17 20:55:03.492192	初始化预加载数据成功, 数据长度:120
# 2019-05-17 20:55:03.492192	策略初始化完成
# 2019-05-17 20:55:03.492192	策略启动完成
# 2019-05-17 20:55:03.492192	回测时间范围:[20180201 23:00:00,20190320 23:00:00)
# 2019-05-17 20:55:03.492192	当前回放的时间段:[20180201 23:00:00,20190320 23:00:00)
# 2019-05-17 20:55:05.925668	准备载入数据：时间段:[20180201 23:00:00 , 20190320 23:00:00), 模式: bar
# 2019-05-17 20:55:14.322977	IF88:CTP： 从本地缓存文件实取65040, 最大应取593280, 还需从数据库取528240
# 2019-05-17 20:55:16.664240	IF88:CTP： 数据库也没能补到缺失的数据
# 2019-05-17 20:55:16.683291	载入完成, 数据量:65040
# 2019-05-17 20:55:16.746462	准备载入数据：时间段:[20180201 07:51:00 , 20180203 23:01:00), 模式: bar
# 2019-05-17 20:55:16.799612	IF88:CTP： 从本地缓存文件实取480, 最大应取3790, 还需从数据库取3310
# 2019-05-17 20:55:16.830717	IF88:CTP： 数据库也没能补到缺失的数据
# 2019-05-17 20:55:16.831742	载入完成, 数据量:480
# 2019-05-17 20:55:17.117480	准备载入数据：时间段:[20171226 02:00:00 , 20180201 07:50:00), 模式: bar
# 2019-05-17 20:55:17.803315	IF88:CTP： 从本地缓存文件实取6240, 最大应取53630, 还需从数据库取47390
# 2019-05-17 20:55:17.980797	IF88:CTP： 数据库也没能补到缺失的数据
# 2019-05-17 20:55:17.983804	载入完成, 数据量:6240
# 2019-05-17 20:55:17.987796	准备载入数据：时间段:[20180203 23:02:00 , 20180204 00:00:00), 模式: bar
# 2019-05-17 20:55:17.988799	IF88:CTP： 从本地缓存文件实取0, 最大应取58, 还需从数据库取58
# 2019-05-17 20:55:18.013867	IF88:CTP： 数据库也没能补到缺失的数据
# 2019-05-17 20:55:18.013867	WARNING: 该时间段:[20180203 23:02:00,20180204 00:00:00) 数据量为0!
# 2019-05-17 20:55:18.997216	当前order：20180322 14:59:00, 买平1, 可平0, 实盘下可能拒单, 请小心处理
# 2019-05-17 20:55:19.787315	当前order：20180525 13:59:00, 买平1, 可平0, 实盘下可能拒单, 请小心处理
# 2019-05-17 20:55:20.681139	当前order：20180802 13:59:00, 买平1, 可平0, 实盘下可能拒单, 请小心处理
# 2019-05-17 20:55:21.086218	当前order：20180903 10:59:00, 买平1, 可平0, 实盘下可能拒单, 请小心处理
# 2019-05-17 20:55:21.502343	当前order：20181010 11:29:00, 买平1, 可平0, 实盘下可能拒单, 请小心处理
# 2019-05-17 20:55:22.130996	当前order：20181123 11:29:00, 买平1, 可平0, 实盘下可能拒单, 请小心处理
# 2019-05-17 20:55:22.339772	当前order：20181207 14:59:00, 买平1, 可平0, 实盘下可能拒单, 请小心处理
# 2019-05-17 20:55:23.614434	回放结束ress: 100%
# 2019-05-17 20:55:23.615417	计算按日统计结果
# 2019-05-17 20:55:23.679588	------------------------------
# 2019-05-17 20:55:23.679588	setting: {'fastPeriod': 20, 'slowPeriod': 80, 'symbolList': ['IF88:CTP']}
# 初始仓位: {'IF88:CTP_LONG': 0, 'IF88:CTP_SHORT': 0}
# 2019-05-17 20:55:23.682616	开始回测
# 2019-05-17 20:55:23.682616	策略初始化
# 2019-05-17 20:55:23.684620	准备载入数据：时间段:[20180201 13:00:00 , 20180201 23:00:00), 模式: bar
# 2019-05-17 20:55:23.708670	IF88:CTP： 从本地缓存文件实取120, 最大应取600, 还需从数据库取480
# 2019-05-17 20:55:23.733755	IF88:CTP： 数据库也没能补到缺失的数据
# 2019-05-17 20:55:23.733755	载入完成, 数据量:120
# 2019-05-17 20:55:23.733755	初始化预加载数据成功, 数据长度:120
# 2019-05-17 20:55:23.733755	策略初始化完成
# 2019-05-17 20:55:23.733755	策略启动完成
# 2019-05-17 20:55:23.733755	回测时间范围:[20180201 23:00:00,20190320 23:00:00)
# 2019-05-17 20:55:23.733755	当前回放的时间段:[20180201 23:00:00,20190320 23:00:00)
# 2019-05-17 20:55:26.229371	准备载入数据：时间段:[20180201 23:00:00 , 20190320 23:00:00), 模式: bar
# 2019-05-17 20:55:34.150460	IF88:CTP： 从本地缓存文件实取65040, 最大应取593280, 还需从数据库取528240
# 2019-05-17 20:55:36.524755	IF88:CTP： 数据库也没能补到缺失的数据
# 2019-05-17 20:55:36.542823	载入完成, 数据量:65040
# 2019-05-17 20:55:36.605971	准备载入数据：时间段:[20180201 07:51:00 , 20180203 23:01:00), 模式: bar
# 2019-05-17 20:55:36.665129	IF88:CTP： 从本地缓存文件实取480, 最大应取3790, 还需从数据库取3310
# 2019-05-17 20:55:36.704292	IF88:CTP： 数据库也没能补到缺失的数据
# 2019-05-17 20:55:36.704292	载入完成, 数据量:480
# 2019-05-17 20:55:36.947939	准备载入数据：时间段:[20171226 02:00:00 , 20180201 07:50:00), 模式: bar
# 2019-05-17 20:55:37.767101	IF88:CTP： 从本地缓存文件实取6240, 最大应取53630, 还需从数据库取47390
# 2019-05-17 20:55:37.949374	IF88:CTP： 数据库也没能补到缺失的数据
# 2019-05-17 20:55:37.952402	载入完成, 数据量:6240
# 2019-05-17 20:55:37.956413	准备载入数据：时间段:[20180203 23:02:00 , 20180204 00:00:00), 模式: bar
# 2019-05-17 20:55:37.958399	IF88:CTP： 从本地缓存文件实取0, 最大应取58, 还需从数据库取58
# 2019-05-17 20:55:37.982490	IF88:CTP： 数据库也没能补到缺失的数据
# 2019-05-17 20:55:37.982490	WARNING: 该时间段:[20180203 23:02:00,20180204 00:00:00) 数据量为0!
# 2019-05-17 20:55:39.744906	当前order：20180529 11:29:00, 买平1, 可平0, 实盘下可能拒单, 请小心处理
# 2019-05-17 20:55:40.613341	当前order：20180803 10:59:00, 买平1, 可平0, 实盘下可能拒单, 请小心处理
# 2019-05-17 20:55:41.062515	当前order：20180906 10:59:00, 买平1, 可平0, 实盘下可能拒单, 请小心处理
# 2019-05-17 20:55:41.435912	当前order：20181011 11:29:00, 买平1, 可平0, 实盘下可能拒单, 请小心处理
# 2019-05-17 20:55:42.094637	当前order：20181123 13:59:00, 买平1, 可平0, 实盘下可能拒单, 请小心处理
# 2019-05-17 20:55:43.523206	回放结束ress: 100%
# 2019-05-17 20:55:43.523206	计算按日统计结果
# 2019-05-17 20:55:43.594418	------------------------------
# 2019-05-17 20:55:43.594418	setting: {'fastPeriod': 30, 'slowPeriod': 40, 'symbolList': ['IF88:CTP']}
# 初始仓位: {'IF88:CTP_LONG': 0, 'IF88:CTP_SHORT': 0}
# 2019-05-17 20:55:43.599409	开始回测
# 2019-05-17 20:55:43.599409	策略初始化
# 2019-05-17 20:55:43.601414	准备载入数据：时间段:[20180201 13:00:00 , 20180201 23:00:00), 模式: bar
# 2019-05-17 20:55:43.626527	IF88:CTP： 从本地缓存文件实取120, 最大应取600, 还需从数据库取480
# 2019-05-17 20:55:43.641545	IF88:CTP： 数据库也没能补到缺失的数据
# 2019-05-17 20:55:43.641545	载入完成, 数据量:120
# 2019-05-17 20:55:43.641545	初始化预加载数据成功, 数据长度:120
# 2019-05-17 20:55:43.641545	策略初始化完成
# 2019-05-17 20:55:43.641545	策略启动完成
# 2019-05-17 20:55:43.641545	回测时间范围:[20180201 23:00:00,20190320 23:00:00)
# 2019-05-17 20:55:43.641545	当前回放的时间段:[20180201 23:00:00,20190320 23:00:00)
# 2019-05-17 20:55:46.051191	准备载入数据：时间段:[20180201 23:00:00 , 20190320 23:00:00), 模式: bar
# 2019-05-17 20:55:54.171793	IF88:CTP： 从本地缓存文件实取65040, 最大应取593280, 还需从数据库取528240
# 2019-05-17 20:55:56.804822	IF88:CTP： 数据库也没能补到缺失的数据
# 2019-05-17 20:55:56.826854	载入完成, 数据量:65040
# 2019-05-17 20:55:56.888024	准备载入数据：时间段:[20180201 07:51:00 , 20180203 23:01:00), 模式: bar
# 2019-05-17 20:55:56.945169	IF88:CTP： 从本地缓存文件实取480, 最大应取3790, 还需从数据库取3310
# 2019-05-17 20:55:56.966225	IF88:CTP： 数据库也没能补到缺失的数据
# 2019-05-17 20:55:56.966225	载入完成, 数据量:480
# 2019-05-17 20:55:57.229985	准备载入数据：时间段:[20171226 02:00:00 , 20180201 07:50:00), 模式: bar
# 2019-05-17 20:55:57.932874	IF88:CTP： 从本地缓存文件实取6240, 最大应取53630, 还需从数据库取47390
# 2019-05-17 20:55:58.125386	IF88:CTP： 数据库也没能补到缺失的数据
# 2019-05-17 20:55:58.127411	载入完成, 数据量:6240
# 2019-05-17 20:55:58.132404	准备载入数据：时间段:[20180203 23:02:00 , 20180204 00:00:00), 模式: bar
# 2019-05-17 20:55:58.133414	IF88:CTP： 从本地缓存文件实取0, 最大应取58, 还需从数据库取58
# 2019-05-17 20:55:58.157491	IF88:CTP： 数据库也没能补到缺失的数据
# 2019-05-17 20:55:58.157491	WARNING: 该时间段:[20180203 23:02:00,20180204 00:00:00) 数据量为0!
# 2019-05-17 20:55:59.124974	当前order：20180322 13:59:00, 买平1, 可平0, 实盘下可能拒单, 请小心处理
# 2019-05-17 20:55:59.930096	当前order：20180525 10:59:00, 买平1, 可平0, 实盘下可能拒单, 请小心处理
# 2019-05-17 20:56:00.859330	当前order：20180802 13:59:00, 买平1, 可平0, 实盘下可能拒单, 请小心处理
# 2019-05-17 20:56:01.281591	当前order：20180904 11:29:00, 买平1, 可平0, 实盘下可能拒单, 请小心处理
# 2019-05-17 20:56:01.680633	当前order：20181010 14:59:00, 买平1, 可平0, 实盘下可能拒单, 请小心处理
# 2019-05-17 20:56:02.326371	当前order：20181123 11:29:00, 买平1, 可平0, 实盘下可能拒单, 请小心处理
# 2019-05-17 20:56:02.533912	当前order：20181210 10:59:00, 买平1, 可平0, 实盘下可能拒单, 请小心处理
# 2019-05-17 20:56:03.755393	回放结束ress: 100%
# 2019-05-17 20:56:03.755393	计算按日统计结果
# 2019-05-17 20:56:03.816554	------------------------------
# 2019-05-17 20:56:03.816554	setting: {'fastPeriod': 30, 'slowPeriod': 60, 'symbolList': ['IF88:CTP']}
# 初始仓位: {'IF88:CTP_LONG': 0, 'IF88:CTP_SHORT': 0}
# 2019-05-17 20:56:03.820574	开始回测
# 2019-05-17 20:56:03.820574	策略初始化
# 2019-05-17 20:56:03.823573	准备载入数据：时间段:[20180201 13:00:00 , 20180201 23:00:00), 模式: bar
# 2019-05-17 20:56:03.846659	IF88:CTP： 从本地缓存文件实取120, 最大应取600, 还需从数据库取480
# 2019-05-17 20:56:03.875726	IF88:CTP： 数据库也没能补到缺失的数据
# 2019-05-17 20:56:03.875726	载入完成, 数据量:120
# 2019-05-17 20:56:03.876729	初始化预加载数据成功, 数据长度:120
# 2019-05-17 20:56:03.876729	策略初始化完成
# 2019-05-17 20:56:03.876729	策略启动完成
# 2019-05-17 20:56:03.876729	回测时间范围:[20180201 23:00:00,20190320 23:00:00)
# 2019-05-17 20:56:03.876729	当前回放的时间段:[20180201 23:00:00,20190320 23:00:00)
# 2019-05-17 20:56:06.392778	准备载入数据：时间段:[20180201 23:00:00 , 20190320 23:00:00), 模式: bar
# 2019-05-17 20:56:14.670797	IF88:CTP： 从本地缓存文件实取65040, 最大应取593280, 还需从数据库取528240
# 2019-05-17 20:56:17.280739	IF88:CTP： 数据库也没能补到缺失的数据
# 2019-05-17 20:56:17.299790	载入完成, 数据量:65040
# 2019-05-17 20:56:17.369978	准备载入数据：时间段:[20180201 07:51:00 , 20180203 23:01:00), 模式: bar
# 2019-05-17 20:56:17.433145	IF88:CTP： 从本地缓存文件实取480, 最大应取3790, 还需从数据库取3310
# 2019-05-17 20:56:17.474085	IF88:CTP： 数据库也没能补到缺失的数据
# 2019-05-17 20:56:17.476091	载入完成, 数据量:480
# 2019-05-17 20:56:17.710738	准备载入数据：时间段:[20171226 02:00:00 , 20180201 07:50:00), 模式: bar
# 2019-05-17 20:56:18.425616	IF88:CTP： 从本地缓存文件实取6240, 最大应取53630, 还需从数据库取47390
# 2019-05-17 20:56:18.600082	IF88:CTP： 数据库也没能补到缺失的数据
# 2019-05-17 20:56:18.603109	载入完成, 数据量:6240
# 2019-05-17 20:56:18.607120	准备载入数据：时间段:[20180203 23:02:00 , 20180204 00:00:00), 模式: bar
# 2019-05-17 20:56:18.607120	IF88:CTP： 从本地缓存文件实取0, 最大应取58, 还需从数据库取58
# 2019-05-17 20:56:18.638942	IF88:CTP： 数据库也没能补到缺失的数据
# 2019-05-17 20:56:18.639961	WARNING: 该时间段:[20180203 23:02:00,20180204 00:00:00) 数据量为0!
# 2019-05-17 20:56:19.616538	当前order：20180323 10:59:00, 买平1, 可平0, 实盘下可能拒单, 请小心处理
# 2019-05-17 20:56:20.447614	当前order：20180529 11:29:00, 买平1, 可平0, 实盘下可能拒单, 请小心处理
# 2019-05-17 20:56:21.336913	当前order：20180803 10:59:00, 买平1, 可平0, 实盘下可能拒单, 请小心处理
# 2019-05-17 20:56:21.716925	当前order：20180831 13:59:00, 买平1, 可平0, 实盘下可能拒单, 请小心处理
# 2019-05-17 20:56:22.141052	当前order：20181011 10:59:00, 买平1, 可平0, 实盘下可能拒单, 请小心处理
# 2019-05-17 20:56:22.732245	当前order：20181123 13:59:00, 买平1, 可平0, 实盘下可能拒单, 请小心处理
# 2019-05-17 20:56:24.280594	回放结束ress: 100%
# 2019-05-17 20:56:24.280594	计算按日统计结果
# 2019-05-17 20:56:24.360829	------------------------------
# 2019-05-17 20:56:24.361829	setting: {'fastPeriod': 30, 'slowPeriod': 80, 'symbolList': ['IF88:CTP']}
# 初始仓位: {'IF88:CTP_LONG': 0, 'IF88:CTP_SHORT': 0}
# 2019-05-17 20:56:24.366821	开始回测
# 2019-05-17 20:56:24.366821	策略初始化
# 2019-05-17 20:56:24.368826	准备载入数据：时间段:[20180201 13:00:00 , 20180201 23:00:00), 模式: bar
# 2019-05-17 20:56:24.389904	IF88:CTP： 从本地缓存文件实取120, 最大应取600, 还需从数据库取480
# 2019-05-17 20:56:24.422990	IF88:CTP： 数据库也没能补到缺失的数据
# 2019-05-17 20:56:24.422990	载入完成, 数据量:120
# 2019-05-17 20:56:24.422990	初始化预加载数据成功, 数据长度:120
# 2019-05-17 20:56:24.422990	策略初始化完成
# 2019-05-17 20:56:24.422990	策略启动完成
# 2019-05-17 20:56:24.422990	回测时间范围:[20180201 23:00:00,20190320 23:00:00)
# 2019-05-17 20:56:24.422990	当前回放的时间段:[20180201 23:00:00,20190320 23:00:00)
# 2019-05-17 20:56:26.935709	准备载入数据：时间段:[20180201 23:00:00 , 20190320 23:00:00), 模式: bar
# 2019-05-17 20:56:35.154569	IF88:CTP： 从本地缓存文件实取65040, 最大应取593280, 还需从数据库取528240
# 2019-05-17 20:56:37.662242	IF88:CTP： 数据库也没能补到缺失的数据
# 2019-05-17 20:56:37.683299	载入完成, 数据量:65040
# 2019-05-17 20:56:37.748494	准备载入数据：时间段:[20180201 07:51:00 , 20180203 23:01:00), 模式: bar
# 2019-05-17 20:56:37.810636	IF88:CTP： 从本地缓存文件实取480, 最大应取3790, 还需从数据库取3310
# 2019-05-17 20:56:37.842709	IF88:CTP： 数据库也没能补到缺失的数据
# 2019-05-17 20:56:37.843711	载入完成, 数据量:480
# 2019-05-17 20:56:38.083352	准备载入数据：时间段:[20171226 02:00:00 , 20180201 07:50:00), 模式: bar
# 2019-05-17 20:56:38.814312	IF88:CTP： 从本地缓存文件实取6240, 最大应取53630, 还需从数据库取47390
# 2019-05-17 20:56:38.998785	IF88:CTP： 数据库也没能补到缺失的数据
# 2019-05-17 20:56:39.001792	载入完成, 数据量:6240
# 2019-05-17 20:56:39.005802	准备载入数据：时间段:[20180203 23:02:00 , 20180204 00:00:00), 模式: bar
# 2019-05-17 20:56:39.006820	IF88:CTP： 从本地缓存文件实取0, 最大应取58, 还需从数据库取58
# 2019-05-17 20:56:39.023872	IF88:CTP： 数据库也没能补到缺失的数据
# 2019-05-17 20:56:39.023872	WARNING: 该时间段:[20180203 23:02:00,20180204 00:00:00) 数据量为0!
# 2019-05-17 20:56:40.837701	当前order：20180530 10:59:00, 买平1, 可平0, 实盘下可能拒单, 请小心处理
# 2019-05-17 20:56:41.757119	当前order：20180803 14:59:00, 买平1, 可平0, 实盘下可能拒单, 请小心处理
# 2019-05-17 20:56:42.228213	当前order：20180906 13:59:00, 买平1, 可平0, 实盘下可能拒单, 请小心处理
# 2019-05-17 20:56:42.604185	当前order：20181011 14:59:00, 买平1, 可平0, 实盘下可能拒单, 请小心处理
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-3f79da7b214d> in <module>
#       2 start = time.time()
#       3 # 执行单线程优化
# ----> 4 resultList = engine.runOptimization(DoubleMaStrategy, setting)
#       5
#       6 print('耗时：%s' %(time.time()-start))
#
# ~\Anaconda3.7\lib\site-packages\vnpy\trader\app\ctaStrategy\ctaBacktesting.py in runOptimization(self, strategyClass, optimizationSetting)
#    1142             self.output('setting: %s' % str(setting))
#    1143             self.initStrategy(strategyClass, setting)
# -> 1144             self.runBacktesting()
#    1145             df = self.calculateDailyResult()
#    1146             # 没有逐日结果，直接返回
#
# ~\Anaconda3.7\lib\site-packages\vnpy\trader\app\ctaStrategy\plugins\ctaBarManager\engine.py in runBacktesting(self)
#      88             self.barManager.register_strategy(self.strategy)
#      89             self.__prev_bars = {}
# ---> 90         super(BacktestingEngine, self).runBacktesting()
#      91
#      92     def newBar(self, bar):
#
# ~\Anaconda3.7\lib\site-packages\vnpy\trader\app\ctaStrategy\ctaBacktesting.py in runBacktesting(self)
#     360                     if idx % oneP == 0:
#     361                         self.output('Progress: %s%%' % str(int(idx / oneP)), True)
# --> 362                     func(data)
#     363                 start = end
#     364
#
# ~\Anaconda3.7\lib\site-packages\vnpy\trader\app\ctaStrategy\plugins\ctaBarManager\engine.py in newBar(self, bar)
#      99                 self.crossLimitOrder(prev_bar)
#     100                 self.crossStopOrder(prev_bar)
# --> 101             self.barManager.on_bar(bar) # equal to: self.strategy.onBar(prev_bar)
#     102             if prev_bar:
#     103                 self.updateDailyClose(prev_bar.vtSymbol, prev_bar.datetime, prev_bar.close)
#
# ~\Anaconda3.7\lib\site-packages\vnpy\trader\app\ctaStrategy\plugins\ctaBarManager\manager.py in on_bar(self, bar)
#     534         manager = self._managers.get(bar.vtSymbol, None)
#     535         if manager:
# --> 536             manager.on_bar(bar)
#     537
#     538     def must_in_trading(self, func):
#
# ~\Anaconda3.7\lib\site-packages\vnpy\trader\app\ctaStrategy\plugins\ctaBarManager\manager.py in on_bar(self, bar)
#     349         bar_1min_finished = None
#     350         for freq in self._low_freqs:
# --> 351             bar_finished = self._update_with_bar(bar, freq)
#     352             if freq == "1m":
#     353                 bar_1min_finished = bar_finished
#
# ~\Anaconda3.7\lib\site-packages\vnpy\trader\app\ctaStrategy\plugins\ctaBarManager\manager.py in _update_with_bar(self, bar, freq)
#     282                         self.override_bar_with_bar(self._push_bars[freq], current_bar)
#     283                     finished_bar = self._push_bars[freq]
# --> 284                     self._am[freq].updateBar(finished_bar)
#     285                 self.override_bar_with_bar(current_bar, bar)
#     286             elif current_bar.datetime <= dt:
#
# ~\Anaconda3.7\lib\site-packages\vnpy\trader\app\ctaStrategy\plugins\ctaBarManager\arraymanager.py in updateBar(self, bar)
#      22     def updateBar(self, bar):
#      23         if bar:
# ---> 24             super(ArrayManager, self).updateBar(bar)
#      25             self.array['datetimeint'][0:self.size - 1] = self.array['datetimeint'][1:self.size]
#      26             self.array['datetimeint'][-1] = dt2int(bar.datetime)
#
# ~\Anaconda3.7\lib\site-packages\vnpy\trader\vtUtility.py in updateBar(self, bar)
#     344             self.array['open'][-1] = float(bar.open)
#     345
# --> 346             self.array['high'][0:self.size - 1] = self.array['high'][1:self.size]
#     347             self.array['high'][-1] = float(bar.high)
#     348
#
# KeyboardInterrupt:

# %%
print(pd.DataFrame(resultList).sort_values(1,  ascending=False))
